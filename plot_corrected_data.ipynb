# %%
import pandas as pd
import matplotlib.pyplot as plt

sh=[1,2,12.0,16.0,20.0,24.0,28.0,32.0,81.0,90.0,99.0,108.0,117.0,126.0,135.0,144.0,153.0,162.0,171.0,180.0,189.0,198.0,207.0,216.0,225.0,234.0,432.0,448.0,464.0,480.0,496.0,512.0,528.0,544.0,560.0,576.0,592.0,608.0,624.0,640.0,656.0,672.0,688.0,704.0,720.0,736.0,752.0,768.0,784.0,800.0,816.0,832.0,848.0,864.0,880.0,896.0,912.0,928.0,944.0,960.0,976.0,992.0,1008.0,1024.0,1040.0,1056.0,1072.0,1088.0,1104.0,1120.0,1136.0,1152.0,1168.0,1184.0,1200.0,1216.0,1232.0,1248.0,1264.0,1280.0,2025.0,2050.0,2075.0,2100.0,2125.0,2150.0,2175.0,2200.0,2225.0,2250.0,2275.0,2300.0,2325.0,2350.0,2375.0,2400.0,2425.0,2450.0,2475.0,2500.0]
hb=[1,2,12.0,16.0,20.0,24.0,28.0,32.0,72.0,80.0,88.0,96.0,104.0,112.0,120.0,128.0,136.0,144.0,152.0,160.0,168.0,176.0,184.0,192.0,200.0,208.0,405.0,420.0,435.0,450.0,465.0,480.0,495.0,510.0,525.0,540.0,555.0,570.0,585.0,600.0,615.0,630.0,645.0,660.0,675.0,690.0,705.0,720.0,735.0,750.0,765.0,780.0,795.0,810.0,825.0,840.0,855.0,870.0,885.0,900.0,915.0,930.0,945.0,960.0,975.0,990.0,1005.0,1020.0,1035.0,1050.0,1065.0,1080.0,1095.0,1110.0,1125.0,1140.0,1155.0,1170.0,1185.0,1200.0,1701.0,1722.0,1743.0,1764.0,1785.0,1806.0,1827.0,1848.0,1869.0,1890.0,1911.0,1932.0,1953.0,1974.0,1995.0,2016.0,2037.0,2058.0,2079.0,2100.0]

#plt.plot('',data=sh, marker='', color='blue', linewidth=2)
#plt.plot('', data=hb, marker='', color='red', linewidth=2)
plt.plot(hb, label='Hyberband')
plt.plot(sh, label='Successive Halving')
plt.legend()
plt.title('Total amount of resources used')
plt.ylabel('Total amount of resources')
plt.xlabel('Budget (R)')
#plt.savefig('./sh-hb-resources.png')

# %%
hb_config=[1,1,5,5,5,5,5,5,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128,128]
sh_config=[1,1,6,6,6,6,6,6,27,27,27,27,27,27,27,27,27,27,27,27,27,27,27,27,27,27,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,108,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405,405]

plt.plot(hb_config, label='Hyberband')
plt.plot(sh_config, label='Successive Halving')
plt.legend()
plt.title('Total amount of unique configurations evaluated')
plt.ylabel('Total amount of unique configurations')
plt.xlabel('Budget (R)')
#plt.savefig('./sh-hb-configs.png')
